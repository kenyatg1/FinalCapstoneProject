# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('API.csv', index_col=False)

# %%
df.head()
# Out:
#    Unnamed: 0  bathrooms  bedrooms              city country currency  \
# 0           0        2.0       3.0             Bronx     USA      USD
# 1           1        3.0       3.0          New York     USA      USD
# 2           2        1.0       3.0  South Ozone Park     USA      USD
# 3           3        2.0       3.0          Flushing     USA      USD
# 4           4        3.0       4.0     Staten Island     USA      USD
#
#    daysOnZillow homeStatus homeStatusForHDP       homeType  ...  \
# 0            -1   FOR_SALE         FOR_SALE          CONDO  ...
# 1            -1   FOR_SALE         FOR_SALE          CONDO  ...
# 2            -1   FOR_SALE         FOR_SALE  SINGLE_FAMILY  ...
# 3            -1   FOR_SALE         FOR_SALE  SINGLE_FAMILY  ...
# 4            -1   FOR_SALE         FOR_SALE      TOWNHOUSE  ...
#
#   listing_sub_type.is_foreclosure  listing_sub_type.is_bankOwned  \
# 0                             NaN                            NaN
# ...

# %% [markdown]
# # Transform data

# %%
df.isna().sum()
# Out:
# Unnamed: 0                               0
# bathrooms                                4
# bedrooms                                 5
# city                                     0
# country                                  0
# currency                                 0
# daysOnZillow                             0
# homeStatus                               0
# homeStatusForHDP                         0
# homeType                                 0
# imgSrc                                   0
# isFeatured                               0
# isNonOwnerOccupied                       0
# isPreforeclosureAuction                  0
# isPremierBuilder                         0
# isShowcaseListing                        0
# isUnmappable                             0
# isZillowOwned                            0
# latitude                                 1
# livingArea                              49
# longitude                                1
# price                                    0
# ...

# %%
# drop columns in middle of dataframe
column = ['Unnamed: 0', 'imgSrc', 'latitude', 'longitude', 'listing_sub_type.is_openHouse', 'open_house_info.open_house_showing', 'newConstructionType',
         'timeOnZillow', 'unit', 'shouldHighlight', 'isFeatured', 'isUnmappable', 'timeOnZillow', 'listing_sub_type.is_FSBA', 'zestimate', 'rentZestimate',
         'lotAreaUnit', 'lotAreaValue', 'daysOnZillow']
df.drop(column, axis=1, inplace=True)

# %%
df
# Out:
#       bathrooms  bedrooms              city country currency homeStatus  \
# 0           2.0       3.0             Bronx     USA      USD   FOR_SALE
# 1           3.0       3.0          New York     USA      USD   FOR_SALE
# 2           1.0       3.0  South Ozone Park     USA      USD   FOR_SALE
# 3           2.0       3.0          Flushing     USA      USD   FOR_SALE
# 4           3.0       4.0     Staten Island     USA      USD   FOR_SALE
# ...         ...       ...               ...     ...      ...        ...
# 2947        3.0       3.0         Charlotte     USA      USD   FOR_SALE
# 2948        3.0       3.0         Charlotte     USA      USD   FOR_SALE
# 2949        3.0       4.0         Charlotte     USA      USD   FOR_SALE
# 2950        3.0       5.0         Charlotte     USA      USD   FOR_SALE
# 2951        3.0       5.0         Charlotte     USA      USD   FOR_SALE
#
#      homeStatusForHDP       homeType  isNonOwnerOccupied  \
# ...

# %%
# drop end columns 
df.drop(df.iloc[:, 20:36], axis=1, inplace=True)

# %%
df
# Out:
#       bathrooms  bedrooms              city country currency homeStatus  \
# 0           2.0       3.0             Bronx     USA      USD   FOR_SALE
# 1           3.0       3.0          New York     USA      USD   FOR_SALE
# 2           1.0       3.0  South Ozone Park     USA      USD   FOR_SALE
# 3           2.0       3.0          Flushing     USA      USD   FOR_SALE
# 4           3.0       4.0     Staten Island     USA      USD   FOR_SALE
# ...         ...       ...               ...     ...      ...        ...
# 2947        3.0       3.0         Charlotte     USA      USD   FOR_SALE
# 2948        3.0       3.0         Charlotte     USA      USD   FOR_SALE
# 2949        3.0       4.0         Charlotte     USA      USD   FOR_SALE
# 2950        3.0       5.0         Charlotte     USA      USD   FOR_SALE
# 2951        3.0       5.0         Charlotte     USA      USD   FOR_SALE
#
#      homeStatusForHDP       homeType  isNonOwnerOccupied  \
# ...

# %% [markdown]
# ## Check for needed transformation

# %%
df.isna().sum()
# Out:
# bathrooms                   4
# bedrooms                    5
# city                        0
# country                     0
# currency                    0
# homeStatus                  0
# homeStatusForHDP            0
# homeType                    0
# isNonOwnerOccupied          0
# isPreforeclosureAuction     0
# isPremierBuilder            0
# isShowcaseListing           0
# isZillowOwned               0
# livingArea                 49
# price                       0
# priceForHDP                 0
# state                       0
# streetAddress               0
# zipcode                     0
# zpid                        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
# check for correct column types
df.dtypes
# Out:
# bathrooms                  float64
# bedrooms                   float64
# city                        object
# country                     object
# currency                    object
# homeStatus                  object
# homeStatusForHDP            object
# homeType                    object
# isNonOwnerOccupied            bool
# isPreforeclosureAuction       bool
# isPremierBuilder              bool
# isShowcaseListing             bool
# isZillowOwned                 bool
# livingArea                 float64
# price                      float64
# priceForHDP                float64
# state                       object
# streetAddress               object
# zipcode                      int64
# zpid                         int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2902 entries, 0 to 2951
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   bathrooms                2902 non-null   float64
#  1   bedrooms                 2902 non-null   float64
#  2   city                     2902 non-null   object
#  3   country                  2902 non-null   object
#  4   currency                 2902 non-null   object
#  5   homeStatus               2902 non-null   object
#  6   homeStatusForHDP         2902 non-null   object
#  7   homeType                 2902 non-null   object
#  8   isNonOwnerOccupied       2902 non-null   bool
#  9   isPreforeclosureAuction  2902 non-null   bool
#  10  isPremierBuilder         2902 non-null   bool
#  11  isShowcaseListing        2902 non-null   bool
#  12  isZillowOwned            2902 non-null   bool
#  13  livingArea               2902 non-null   float64
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Fix upper limit

# %%
# Any price above 750000 gets excluded
df = df.loc[df['price']<=750000]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1899 entries, 0 to 2951
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   bathrooms                1899 non-null   float64
#  1   bedrooms                 1899 non-null   float64
#  2   city                     1899 non-null   object
#  3   country                  1899 non-null   object
#  4   currency                 1899 non-null   object
#  5   homeStatus               1899 non-null   object
#  6   homeStatusForHDP         1899 non-null   object
#  7   homeType                 1899 non-null   object
#  8   isNonOwnerOccupied       1899 non-null   bool
#  9   isPreforeclosureAuction  1899 non-null   bool
#  10  isPremierBuilder         1899 non-null   bool
#  11  isShowcaseListing        1899 non-null   bool
#  12  isZillowOwned            1899 non-null   bool
#  13  livingArea               1899 non-null   float64
# ...

# %% [markdown]
# ### Change suburbs to proper city names

# %%
df['city'].unique()
# Out:
# array(['Bronx', 'New York', 'South Ozone Park', 'Staten Island',
#        'Jamaica', 'Manhattan', 'Brooklyn', 'Forest Hills', 'Woodhaven',
#        'Kew Gardens', 'Whitestone', 'Bayside', 'Far Rockaway',
#        'Bellerose', 'Flushing', 'Glen Oaks', 'Howard Beach', 'Woodside',
#        'New Hyde Park', 'Queens Village', 'Jackson Heights',
#        'Staten island', 'Kew Garden Hl', 'Oakland Gardens', 'Little Neck',
#        'Springfield Gardens', 'Richmond Hill', 'Saint Albans',
#        'Fresh Meadows', 'Queens', 'Rego Park', 'Astoria', 'Rockaway Park',
#        'East Elmhurst', 'Broad Channel', 'Corona', 'Miami', 'South Miami',
#        'Cutler Bay', 'Goulds', 'Doral', 'Charlotte', 'Matthews',
#        'Mooresville'], dtype=object)

# %%
# get zip codes by city
zipcodes = df['zipcode'].unique()
zipcodes.sort()
zipcodes
# Out:
# array([10002, 10007, 10009, 10010, 10019, 10021, 10022, 10023, 10024,
#        10025, 10026, 10027, 10028, 10029, 10030, 10031, 10032, 10033,
#        10034, 10035, 10036, 10037, 10040, 10065, 10075, 10128, 10301,
#        10302, 10303, 10304, 10305, 10306, 10307, 10308, 10309, 10310,
#        10312, 10314, 10451, 10452, 10453, 10455, 10456, 10457, 10458,
#        10459, 10460, 10461, 10462, 10463, 10464, 10465, 10466, 10467,
#        10468, 10469, 10470, 10471, 10473, 10475, 11004, 11040, 11105,
#        11106, 11201, 11203, 11206, 11207, 11208, 11209, 11210, 11211,
#        11212, 11213, 11214, 11215, 11217, 11218, 11220, 11221, 11223,
#        11225, 11226, 11229, 11230, 11233, 11234, 11235, 11236, 11237,
#        11238, 11354, 11355, 11357, 11360, 11361, 11362, 11363, 11364,
#        11365, 11367, 11368, 11369, 11372, 11374, 11375, 11377, 11378,
#        11379, 11411, 11412, 11413, 11414, 11415, 11416, 11418, 11419,
# ...

# %%
# set lists for zip codes of each city
new_york_zip = []
charlotte_zip  = []
miami_zip = []

for zip in zipcodes:
    if zip < 20000:
        new_york_zip.append(zip)
    elif 20000 < zip < 30000:
        charlotte_zip.append(zip)
    else:
        miami_zip.append(zip)

# %%
# change city based off zip codes
df.loc[df['zipcode'].isin(new_york_zip), 'city'] = 'New York'
df.loc[df['zipcode'].isin(miami_zip), 'city'] = 'Miami'
df.loc[df['zipcode'].isin(charlotte_zip), 'city'] = 'Charlotte'

# %%
# check if it worked
df['city'].unique()
# Out:
# array(['New York', 'Miami', 'Charlotte'], dtype=object)

# %% [markdown]
# # Cursory Data Visualization

# %%
plt.figure(figsize=(12,8))
sns.boxplot(df, x='homeType', y='price')
# Out:
# <Axes: xlabel='homeType', ylabel='price'>

# %% [markdown]
# # Upload to PGAdmin4

# %%
# from sqlalchemy import create_engine
# engine = create_engine(f'postgresql+psycopg2://postgres:password@127.0.0.1:5433/final_project')

# %%
# with engine.connect() as conn:
#     df.to_sql('final_project', con=conn, index=False, if_exists='replace')
