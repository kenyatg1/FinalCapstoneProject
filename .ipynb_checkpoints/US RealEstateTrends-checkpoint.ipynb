# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import NearestNeighbors
from matplotlib.colors import Normalize
from matplotlib.cm import ScalarMappable

# %% [markdown]
# 1) DATA VERIFICATION & PROCESSING

# %%
df_cleaned = pd.read_csv('USRealEstateTrends.csv')
df.head()
# Out:
#    RegionID  SizeRank       RegionName StateName  2018-02-HomeValue  \
# 0    102001         0    United States       NaN      225746.614318
# 1    394913         1     New York, NY        NY      468313.430126
# 2    753899         2  Los Angeles, CA        CA      629019.165765
# 3    394463         3      Chicago, IL        IL      229741.266973
# 4    394514         4       Dallas, TX        TX      241533.231800
#
#    2018-02-DaysPending  2018-02-CutRaw  2018-03-HomeValue  \
# 0                 52.0          7600.0      227155.648994
# 1                 68.0         16000.0      470102.249154
# 2                 33.0         20000.0      636850.139417
# 3                 52.0          8000.0      231317.183706
# 4                 46.0          8562.0      243401.180622
#
#    2018-03-DaysPending  2018-03-CutRaw  ...  2024-02-CutRaw  \
# 0                 48.0          8900.0  ...         10000.0
# 1                 63.0         19751.5  ...         25000.0
# 2                 31.0         20000.0  ...         30000.5
# 3                 42.0          9100.0  ...         10000.0
# 4                 42.0          9900.0  ...         10000.0
#
#    2024-03-HomeValue  2024-03-DaysPending  2024-03-CutRaw  2024-04-HomeValue  \
# 0      357374.362080                 42.0         10000.0      359240.114070
# 1      646508.747102                 55.0         25000.0      652619.099940
# 2      952665.578913                 32.0         34000.0      956266.687926
# 3      316875.294320                 29.0         10000.0      319764.144323
# 4      379972.349667                 42.0         10000.0      380957.392395
#
#    2024-04-DaysPending  2024-04-CutRaw  2024-05-HomeValue  \
# 0                 38.0         10000.0      360681.294250
# 1                 51.0         26000.0      657279.223513
# 2                 29.0         40012.0      962388.491425
# 3                 25.0         10000.0      321897.252361
# 4                 38.0         10000.0      381103.625851
#
#    2024-05-DaysPending  2024-05-CutRaw
# 0                 37.0         10000.0
# 1                 47.0         30000.0
# 2                 28.0         40000.0
# 3                 23.0         10000.0
# 4                 38.0         10000.0
#
# [5 rows x 232 columns]

# %%
print(df_cleaned.columns)
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'StateName', '2018-02-HomeValue',
#        '2018-02-DaysPending', '2018-02-CutRaw', '2018-03-HomeValue',
#        '2018-03-DaysPending', '2018-03-CutRaw',
#        ...
#        '2024-02-CutRaw', '2024-03-HomeValue', '2024-03-DaysPending',
#        '2024-03-CutRaw', '2024-04-HomeValue', '2024-04-DaysPending',
#        '2024-04-CutRaw', '2024-05-HomeValue', '2024-05-DaysPending',
#        '2024-05-CutRaw'],
#       dtype='object', length=232)

# %%
df_cleaned.rename(columns=lambda col: col.replace("CutRaw", "PriceCut") if "CutRaw" in col else col, inplace=True)

# %%
print(df_cleaned.columns)
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'StateName', '2018-02-HomeValue',
#        '2018-02-DaysPending', '2018-02-PriceCut', '2018-03-HomeValue',
#        '2018-03-DaysPending', '2018-03-PriceCut',
#        ...
#        '2024-02-PriceCut', '2024-03-HomeValue', '2024-03-DaysPending',
#        '2024-03-PriceCut', '2024-04-HomeValue', '2024-04-DaysPending',
#        '2024-04-PriceCut', '2024-05-HomeValue', '2024-05-DaysPending',
#        '2024-05-PriceCut'],
#       dtype='object', length=232)

# %%
# Dictionary
city_summary = {}

# Loop through each city to calculate mean, summary, and quantity of data
for city in cities:
    city_data = df_cleaned[df_cleaned['RegionName'] == city]

    home_value_cols = [col for col in city_data.columns if 'HomeValue' in col]
    
    mean_home_value = city_data[home_value_cols].mean().mean()  
    
    summary_stats = city_data[home_value_cols].describe()
   
    quantity = city_data[home_value_cols].notna().sum().sum() 
    
    #RESULTS
    city_summary[city] = {
        'Mean Home Value': mean_home_value,
        'Quantity': quantity
    }

summary_df = pd.DataFrame(city_summary).T
print(summary_df)
# Out:
#                  Mean Home Value  Quantity
# United States      291647.486020      76.0
# New York, NY       551761.259918      76.0
# Los Angeles, CA    790001.304165      76.0
# Chicago, IL        268338.572150      76.0
# Dallas, TX         311161.950944      76.0
# ...                          ...       ...
# Zapata, TX         129485.123752      76.0
# Ketchikan, AK      357956.315713      76.0
# Craig, CO          221233.934525      76.0
# Vernon, TX          86252.578517      76.0
# Lamesa, TX          96494.068519      76.0
#
# [895 rows x 2 columns]

# %%
print(df_cleaned['RegionName'].unique())
# Out:
# ['United States' 'New York, NY' 'Los Angeles, CA' 'Chicago, IL'
#  'Dallas, TX' 'Houston, TX' 'Washington, DC' 'Philadelphia, PA'
#  'Miami, FL' 'Atlanta, GA' 'Boston, MA' 'Phoenix, AZ' 'San Francisco, CA'
#  'Riverside, CA' 'Detroit, MI' 'Seattle, WA' 'Minneapolis, MN'
#  'San Diego, CA' 'Tampa, FL' 'Denver, CO' 'Baltimore, MD' 'St. Louis, MO'
#  'Orlando, FL' 'Charlotte, NC' 'San Antonio, TX' 'Portland, OR'
#  'Sacramento, CA' 'Pittsburgh, PA' 'Cincinnati, OH' 'Austin, TX'
#  'Las Vegas, NV' 'Kansas City, MO' 'Columbus, OH' 'Indianapolis, IN'
#  'Cleveland, OH' 'San Jose, CA' 'Nashville, TN' 'Virginia Beach, VA'
#  'Providence, RI' 'Jacksonville, FL' 'Milwaukee, WI' 'Oklahoma City, OK'
#  'Raleigh, NC' 'Memphis, TN' 'Richmond, VA' 'Louisville, KY'
#  'New Orleans, LA' 'Salt Lake City, UT' 'Hartford, CT' 'Buffalo, NY'
#  'Birmingham, AL' 'Rochester, NY' 'Grand Rapids, MI' 'Tucson, AZ'
#  'Urban Honolulu, HI' 'Tulsa, OK' 'Fresno, CA' 'Worcester, MA' 'Omaha, NE'
#  'Bridgeport, CT' 'Greenville, SC' 'Albuquerque, NM' 'Bakersfield, CA'
#  'Albany, NY' 'Knoxville, TN' 'Baton Rouge, LA' 'McAllen, TX'
#  'New Haven, CT' 'El Paso, TX' 'Allentown, PA' 'Oxnard, CA' 'Columbia, SC'
#  'North Port, FL' 'Charleston, SC' 'Greensboro, NC' 'Stockton, CA'
#  'Cape Coral, FL' 'Boise City, ID' 'Colorado Springs, CO'
#  'Little Rock, AR' 'Lakeland, FL' 'Akron, OH' 'Des Moines, IA'
#  'Springfield, MA' 'Ogden, UT' 'Madison, WI' 'Winston, NC' 'Deltona, FL'
#  'Syracuse, NY' 'Provo, UT' 'Toledo, OH' 'Wichita, KS' 'Durham, NC'
#  'Augusta, GA' 'Palm Bay, FL' 'Jackson, MS' 'Harrisburg, PA' 'Spokane, WA'
#  'Scranton, PA' 'Chattanooga, TN' 'Modesto, CA' 'Lancaster, PA'
#  'Portland, ME' 'Youngstown, OH' 'Lansing, MI' 'Fayetteville, AR'
#  'Fayetteville, NC' 'Lexington, KY' 'Pensacola, FL' 'Santa Rosa, CA'
#  'Reno, NV' 'Huntsville, AL' 'Port St. Lucie, FL' 'Lafayette, LA'
#  'Myrtle Beach, SC' 'Springfield, MO' 'Visalia, CA' 'Killeen, TX'
#  'Asheville, NC' 'York, PA' 'Vallejo, CA' 'Santa Maria, CA' 'Salinas, CA'
#  'Salem, OR' 'Mobile, AL' 'Reading, PA' 'Corpus Christi, TX'
#  'Brownsville, TX' 'Manchester, NH' 'Fort Wayne, IN' 'Gulfport, MS'
#  'Salisbury, MD' 'Flint, MI' 'Peoria, IL' 'Canton, OH' 'Savannah, GA'
#  'Anchorage, AK' 'Beaumont, TX' 'Shreveport, LA' 'Trenton, NJ'
#  'Montgomery, AL' 'Davenport, IA' 'Tallahassee, FL' 'Eugene, OR'
#  'Naples, FL' 'Ann Arbor, MI' 'Ocala, FL' 'Hickory, NC' 'Huntington, WV'
#  'Fort Collins, CO' 'Rockford, IL' 'Lincoln, NE' 'Gainesville, FL'
#  'Boulder, CO' 'Green Bay, WI' 'Columbus, GA' 'South Bend, IN'
#  'Spartanburg, SC' 'Greeley, CO' 'Lubbock, TX' 'Clarksville, TN'
#  'Roanoke, VA' 'Evansville, IN' 'Kingsport, TN' 'Kennewick, WA'
#  'Utica, NY' 'Hagerstown, MD' 'Duluth, MN' 'Olympia, WA' 'Longview, TX'
#  'Wilmington, NC' 'San Luis Obispo, CA' 'Crestview, FL' 'Merced, CA'
#  'Waco, TX' 'Cedar Rapids, IA' 'Atlantic City, NJ' 'Bremerton, WA'
#  'Sioux Falls, SD' 'Santa Cruz, CA' 'Erie, PA' 'Norwich, CT'
#  'Amarillo, TX' 'Laredo, TX' 'Tuscaloosa, AL' 'College Station, TX'
#  'Kalamazoo, MI' 'Lynchburg, VA' 'Charleston, WV' 'Yakima, WA' 'Fargo, ND'
#  'Binghamton, NY' 'Fort Smith, AR' 'Appleton, WI' 'Topeka, KS' 'Macon, GA'
#  'Tyler, TX' 'Barnstable Town, MA' 'Daphne, AL' 'Bellingham, WA'
#  'Burlington, VT' 'Rochester, MN' 'Lafayette, IN' 'Champaign, IL'
#  'Medford, OR' 'Charlottesville, VA' 'Lake Charles, LA' 'Las Cruces, NM'
#  'Chico, CA' 'Hilton Head Island, SC' 'Athens, GA' 'Lake Havasu City, AZ'
#  'Columbia, MO' 'Springfield, IL' 'Houma, LA' 'Monroe, LA' 'Elkhart, IN'
#  'Johnson City, TN' 'Yuma, AZ' 'Gainesville, GA' 'Jacksonville, NC'
#  'Florence, SC' 'Hilo, HI' 'St. Cloud, MN' 'Racine, WI' 'Bend, OR'
#  'Saginaw, MI' 'Warner Robins, GA' 'Terre Haute, IN' 'Torrington, CT'
#  'Punta Gorda, FL' 'Billings, MT' 'Redding, CA' 'Kingston, NY'
#  'Panama City, FL' 'Joplin, MO' 'Dover, DE' 'El Centro, CA' 'Jackson, TN'
#  'Yuba City, CA' 'Bowling Green, KY' 'St. George, UT' 'Muskegon, MI'
#  'Abilene, TX' 'Iowa City, IA' 'Auburn, AL' 'Midland, TX'
#  'Bloomington, IL' 'Hattiesburg, MS' 'Oshkosh, WI' 'Eau Claire, WI'
#  'Greenville, NC' 'Burlington, NC' 'Waterloo, IA' "Coeur d'Alene, ID"
#  'East Stroudsburg, PA' 'Pueblo, CO' 'Blacksburg, VA' 'Wausau, WI'
#  'Kahului, HI' 'Janesville, WI' 'Tupelo, MS' 'Bloomington, IN'
#  'Odessa, TX' 'Jackson, MI' 'State College, PA' 'Sebastian, FL'
#  'Madera, CA' 'Decatur, AL' 'Chambersburg, PA' 'Vineland, NJ'
#  'Idaho Falls, ID' 'Grand Junction, CO' 'Elizabethtown, KY' 'Niles, MI'
#  'Monroe, MI' 'Santa Fe, NM' 'Concord, NH' 'Alexandria, LA'
#  'Traverse City, MI' 'Bangor, ME' 'Homosassa Springs, FL' 'Hanford, CA'
#  'Jefferson City, MO' 'Florence, AL' 'Dothan, AL' 'London, KY'
#  'Albany, GA' 'Sioux City, IA' 'Wichita Falls, TX' 'Texarkana, TX'
#  'Valdosta, GA' 'Logan, UT' 'Flagstaff, AZ' 'Rocky Mount, NC'
#  'Pottsville, PA' 'Dalton, GA' 'Lebanon, PA' 'Morristown, TN'
#  'Winchester, VA' 'Wheeling, WV' 'Morgantown, WV' 'La Crosse, WI'
#  'Napa, CA' 'Rapid City, SD' 'Sumter, SC' 'Eureka, CA' 'Springfield, OH'
#  'Harrisonburg, VA' 'Battle Creek, MI' 'Sherman, TX' 'Manhattan, KS'
#  'Carbondale, IL' 'Johnstown, PA' 'Jonesboro, AR' 'Bismarck, ND'
#  'Hammond, LA' 'Pittsfield, MA' 'Mount Vernon, WA' 'Jamestown, NY'
#  'The Villages, FL' 'Albany, OR' 'Glens Falls, NY' 'Lawton, OK'
#  'Cleveland, TN' 'Sierra Vista, AZ' 'Ames, IA' 'Mansfield, OH'
#  'Staunton, VA' 'Augusta, ME' 'Altoona, PA' 'New Bern, NC'
#  'Farmington, NM' 'St. Joseph, MO' 'San Angelo, TX' 'Wenatchee, WA'
#  'Owensboro, KY' 'Holland, MI' 'Lumberton, NC' 'Lawrence, KS'
#  'Goldsboro, NC' 'Watertown, NY' 'Sheboygan, WI' 'Weirton, WV'
#  'Missoula, MT' 'Bozeman, MT' 'Anniston, AL' 'Beckley, WV'
#  'Williamsport, PA' 'Brunswick, GA' 'Twin Falls, ID' 'California, MD'
#  'Cookeville, TN' 'Muncie, IN' 'Michigan City, IN' 'Roseburg, OR'
#  'Lewiston, ME' 'Longview, WA' 'Ogdensburg, NY' 'Kankakee, IL'
#  'Bluefield, WV' 'Show Low, AZ' 'Richmond, KY' 'Tullahoma, TN'
#  'Whitewater, WI' 'Ithaca, NY' 'Grand Forks, ND' 'Decatur, IL'
#  'LaGrange, GA' 'Bay City, MI' 'Fond du Lac, WI' 'Gettysburg, PA'
#  'Gadsden, AL' 'Kalispell, MT' 'Danville, VA' 'Mankato, MN' 'Lima, OH'
#  'Salem, OH' 'Truckee, CA' 'Sebring, FL' 'Cheyenne, WY' 'Hot Springs, AR'
#  'Adrian, MI' 'Shelby, NC' 'Dubuque, IA' 'Meridian, MS' 'Pinehurst, NC'
#  'Paducah, KY' 'Victoria, TX' 'Rome, GA' 'Sevierville, TN'
#  'Moses Lake, WA' 'Ashtabula, OH' 'Cape Girardeau, MO' 'Albertville, AL'
#  'Fairbanks, AK' 'Brainerd, MN' 'Cumberland, MD' 'Ocean City, NJ'
#  'Corvallis, OR' 'Pocatello, ID' 'Corning, NY' 'New Philadelphia, OH'
#  'Sunbury, PA' 'Ukiah, CA' 'Hermiston, OR' 'Clarksburg, WV'
#  'Parkersburg, WV' 'Beaver Dam, WI' 'Pine Bluff, AR' 'Grants Pass, OR'
#  'Cullman, AL' 'Lufkin, TX' 'Zanesville, OH' 'New Castle, PA'
#  'Oak Harbor, WA' 'Orangeburg, SC' 'Watertown, WI' 'Meadville, PA'
#  'Elmira, NY' 'Great Falls, MT' 'Laurel, MS' 'Russellville, AR'
#  'Indiana, PA' 'Midland, MI' 'Kokomo, IN' 'Bloomsburg, PA' 'Opelousas, LA'
#  'Helena, MT' 'Key West, FL' 'Talladega, AL' 'Stillwater, OK'
#  'Columbus, IN' 'Athens, TX' 'Centralia, WA' 'Manitowoc, WI'
#  'Hinesville, GA' 'DuBois, PA' 'Warsaw, IN' 'Plattsburgh, NY'
#  'Statesboro, GA' 'Casper, WY' 'Wilson, NC' 'Glenwood Springs, CO'
#  'Seneca, SC' 'Minot, ND' 'Olean, NY' 'Chillicothe, OH' 'Searcy, AR'
#  'Grand Island, NE' 'Port Angeles, WA' 'Auburn, NY' 'Huntsville, TX'
#  'Keene, NH' 'Heber, UT' 'Quincy, IL' 'Sandusky, OH' 'Findlay, OH'
#  'Frankfort, KY' 'Danville, IL' 'Aberdeen, WA' 'Portsmouth, OH'
#  'Somerset, PA' 'Wisconsin Rapids, WI' 'Jefferson, GA' 'Kapaa, HI'
#  'Palatka, FL' 'Gallup, NM' 'Hobbs, NM' 'Shawnee, OK' 'Mount Airy, NC'
#  'Stevens Point, WI' 'Greeneville, TN' 'Greenwood, SC' 'Lake City, FL'
#  'Klamath Falls, OR' 'Morehead City, NC' 'Clearlake, CA' 'Alamogordo, NM'
#  'Roanoke Rapids, NC' 'Farmington, MO' 'Muskogee, OK' 'Marion, IN'
#  'Faribault, MN' 'Richmond, IN' 'Marquette, MI' 'North Wilkesboro, NC'
#  'Mount Pleasant, MI' 'Rio Grande City, TX' 'Marion, OH' 'Baraboo, WI'
#  'Red Bluff, CA' 'Marinette, WI' 'Roswell, NM' 'Shelton, WA' 'Dublin, GA'
#  'Nacogdoches, TX' 'Somerset, KY' 'Coos Bay, OR' 'Forest City, NC'
#  'Martinsville, VA' 'Rexburg, ID' 'Lewiston, ID' 'Laconia, NH'
#  'Georgetown, SC' 'Athens, OH' 'Sanford, NC' 'Enid, OK' 'Mount Vernon, OH'
#  'Walla Walla, WA' 'Albemarle, NC' 'Hutchinson, KS' 'Hudson, NY'
#  'Starkville, MS' 'Carlsbad, NM' 'Gillette, WY' 'Sturgis, MI'
#  'Rutland, VT' 'Crossville, TN' 'Sayre, PA' 'Salina, KS' 'Marietta, OH'
#  'Fergus Falls, MN' 'Barre, VT' 'Fremont, OH' 'Oneonta, NY' 'Columbus, MS'
#  'Norwalk, OH' 'Batavia, NY' 'Ardmore, OK' 'Palestine, TX'
#  'Fort Madison, IA' 'Charleston, IL' 'Fernley, NV' 'Carson City, NV'
#  'Eagle Pass, TX' 'Calhoun, GA' 'Cullowhee, NC' 'Kearney, NE'
#  'Fairmont, WV' 'Ontario, OR' 'Gaffney, SC' 'Picayune, MS' 'Sterling, IL'
#  'Branson, MO' 'Cedar City, UT' 'Waycross, GA' 'Oxford, MS' 'Jasper, IN'
#  'Edwards, CO' 'Durango, CO' 'Kinston, NC' 'Sonora, CA' 'Tiffin, OH'
#  'Batesville, AR' 'Point Pleasant, WV' 'Elko, NV' 'Danville, KY'
#  'Glasgow, KY' 'St. Marys, GA' 'Boone, NC' 'Warrensburg, MO'
#  'Gloversville, NY' 'Fort Leonard Wood, MO' 'Poplar Bluff, MO'
#  'Elizabeth City, NC' 'Payson, AZ' 'Athens, TN' 'Enterprise, AL'
#  'Ashland, OH' 'Scottsboro, AL' 'Milledgeville, GA' 'Kerrville, TX'
#  'Bartlesville, OK' 'Platteville, WI' 'Corsicana, TX' 'Greenville, OH'
#  'Rochelle, IL' 'Douglas, GA' 'Oil City, PA' 'Mason City, IA'
#  'Jacksonville, TX' 'Galesburg, IL' 'Pahrump, NV' 'Paris, TX' 'Winona, MN'
#  'Newport, OR' 'Morgan City, LA' 'Shelbyville, TN' 'Amsterdam, NY'
#  'Ozark, AL' 'Alice, TX' 'Gardnerville Ranchos, NV' 'Fort Polk South, LA'
#  'Ca-¦on City, CO' 'Natchez, MS' 'New Castle, IN' 'Clovis, NM'
#  'Norfolk, NE' 'Cadillac, MI' 'Ruston, LA' 'Sidney, OH' 'Pullman, WA'
#  'Malone, NY' 'Del Rio, TX' 'Blackfoot, ID' 'Red Wing, MN' 'Nogales, AZ'
#  'Tahlequah, OK' 'Kendallville, IN' 'Montrose, CO' 'Cortland, NY'
#  'Mount Sterling, KY' 'Clinton, IA' 'Sandpoint, ID' 'Bardstown, KY'
#  'Wapakoneta, OH' 'Plymouth, IN' 'Lewistown, PA' 'Bemidji, MN'
#  'Bellefontaine, OH' 'Seymour, IN' 'Burley, ID' 'Durant, OK'
#  'Moultrie, GA' 'Bogalusa, LA' 'Cornelia, GA' 'Hillsdale, MI'
#  'Thomasville, GA' 'Paragould, AR' 'Greenville, MS' 'Burlington, IA'
#  'Madisonville, KY' 'Menomonie, WI' 'Shawano, WI' 'Vicksburg, MS'
#  'Bedford, IN' 'Washington, NC' 'Freeport, IL' 'Harrison, AR' 'Rolla, MO'
#  'Coldwater, MI' 'Marion, NC' 'Huntingdon, PA' 'Ellensburg, WA'
#  'Ponca City, OK' 'Lawrenceburg, TN' 'McAlester, OK' 'Mount Pleasant, TX'
#  'Willmar, MN' 'Rockingham, NC' 'Muscatine, IA' 'Lewisburg, PA'
#  'Auburn, IN' 'Duncan, OK' 'Sedalia, MO' 'Cedartown, GA' 'Henderson, NC'
#  'Aberdeen, SD' 'Rock Springs, WY' 'Garden City, KS' 'Stephenville, TX'
#  'Celina, OH' 'Wilmington, OH' 'Bucyrus, OH' 'Alma, MI' 'El Campo, TX'
#  'Mountain Home, AR' 'Gainesville, TX' 'Tifton, GA' 'Blytheville, AR'
#  'McMinnville, TN' 'Astoria, OR' 'Bradford, PA' 'Espa-¦ola, NM'
#  'McComb, MS' 'Big Stone Gap, VA' 'Marshalltown, IA' 'Big Rapids, MI'
#  'Austin, MN' 'Selinsgrove, PA' 'West Plains, MO' 'Okeechobee, FL'
#  'Houghton, MI' 'Moscow, ID' 'Clewiston, FL' 'Riverton, WY'
#  'El Dorado, AR' 'Selma, AL' 'Pittsburg, KS' 'Hannibal, MO' 'Warren, PA'
#  'Alexandria, MN' 'Urbana, OH' 'Greenwood, MS' 'Cambridge, OH'
#  'Williston, ND' 'Defiance, OH' 'Sikeston, MO' 'Safford, AZ'
#  'Jacksonville, IL' 'Ada, OK' 'Brownwood, TX' 'Crawfordsville, IN'
#  'Logansport, IN' 'Scottsbluff, NE' 'Natchitoches, LA' 'Newberry, SC'
#  'Lock Haven, PA' 'Centralia, IL' 'Easton, MD' 'Owatonna, MN'
#  'Mount Vernon, IL' 'Laramie, WY' 'Murray, KY' 'Fremont, NE'
#  'Bennington, VT' 'Sault Ste. Marie, MI' 'Campbellsville, KY'
#  'Dyersburg, TN' 'Escanaba, MI' 'Mayfield, KY' 'Kill Devil Hills, NC'
#  'Sulphur Springs, TX' 'Hutchinson, MN' 'Coshocton, OH' 'Huntington, IN'
#  'DeRidder, LA' 'Vincennes, IN' 'Bay City, TX' 'North Platte, NE'
#  'Peru, IN' 'Pontiac, IL' 'Lebanon, MO' 'Newport, TN' 'Decatur, IN'
#  'Vidalia, GA' 'Brenham, TX' 'Vernal, UT' 'Ottumwa, IA' 'Butte, MT'
#  'Corinth, MS' 'Brookhaven, MS' 'Emporia, KS' 'Jackson, WY'
#  'Big Spring, TX' 'Effingham, IL' 'Dodge City, KS' 'Watertown, SD'
#  'Angola, IN' 'Dixon, IL' 'Laurinburg, NC' 'Taos, NM' 'Brookings, SD'
#  'Americus, GA' 'Columbus, NE' 'Taylorville, IL' 'Arcadia, FL'
#  'Lewisburg, TN' 'Seneca Falls, NY' 'Dickinson, ND' 'Washington, IN'
#  'Troy, AL' 'Malvern, AR' 'Frankfort, IN' 'Madison, IN' 'Brevard, NC'
#  'Susanville, CA' 'Martin, TN' 'Plainview, TX' 'Dayton, TN' 'Jackson, OH'
#  'Cambridge, MD' 'Paris, TN' 'Juneau, AK' 'Coffeyville, KS'
#  'Las Vegas, NM' 'Berlin, NH' 'Cleveland, MS' 'Hastings, NE'
#  'Beeville, TX' 'Kingsville, TX' 'Wabash, IN' 'Breckenridge, CO'
#  'Albert Lea, MN' 'Sheridan, WY' 'Union City, TN' 'Miami, OK'
#  'Iron Mountain, MI' 'Jesup, GA' 'McPherson, KS' 'Kirksville, MO'
#  'Ludington, MI' 'Bainbridge, GA' 'Alpena, MI'
#  'Washington Court House, OH' 'Hays, KS' 'Fort Morgan, CO' 'Van Wert, OH'
#  'Kennett, MO' 'Weatherford, OK' 'Mountain Home, ID' 'Mineral Wells, TX'
#  'Lincoln, IL' 'Silver City, NM' 'Elkins, WV' 'Macomb, IL' 'Camden, AR'
#  'Crescent City, CA' 'North Vernon, IN' 'Thomaston, GA' 'Grants, NM'
#  'Bennettsville, SC' 'Fredericksburg, TX' 'Toccoa, GA' 'The Dalles, OR'
#  'Greensburg, IN' 'Indianola, MS' 'La Grande, OR' 'Ottawa, KS'
#  'New Ulm, MN' 'Lexington, NE' 'Great Bend, KS' 'Spearfish, SD'
#  'Wauchula, FL' 'Marshall, MN' 'Deming, NM' 'Mexico, MO' 'Fallon, NV'
#  'Altus, OK' 'Uvalde, TX' 'Hailey, ID' 'Steamboat Springs, CO'
#  'Summerville, GA' 'Moberly, MO' 'Middlesborough, KY' 'Woodward, OK'
#  'Prineville, OR' 'Hood River, OR' 'Forrest City, AR' 'Connersville, IN'
#  'Mitchell, SD' 'Marshall, MO' 'Brookings, OR' 'Yankton, SD'
#  'Wahpeton, ND' 'Magnolia, AR' 'Elk City, OK' 'Worthington, MN'
#  'Liberal, KS' 'Oskaloosa, IA' 'Pampa, TX' 'Clarksdale, MS' 'Sterling, CO'
#  'Beatrice, NE' 'Jamestown, ND' 'Levelland, TX' 'Grenada, MS'
#  'Maryville, MO' 'Arkadelphia, AR' 'Dumas, TX' 'Guymon, OK' 'Borger, TX'
#  'Pierre, SD' 'Huron, SD' 'Storm Lake, IA' 'Cordele, GA' 'Evanston, WY'
#  'Raymondville, TX' 'Port Lavaca, TX' 'Othello, WA' 'Vineyard Haven, MA'
#  'Parsons, KS' 'Price, UT' 'Portales, NM' 'Los Alamos, NM' 'Hereford, TX'
#  'Andrews, TX' 'Spirit Lake, IA' 'Fitzgerald, GA' 'Winnemucca, NV'
#  'Maysville, KY' 'Snyder, TX' 'Helena, AR' 'Spencer, IA' 'Atchison, KS'
#  'Fairfield, IA' 'Vermillion, SD' 'Sweetwater, TX' 'Pecos, TX'
#  'Zapata, TX' 'Ketchikan, AK' 'Craig, CO' 'Vernon, TX' 'Lamesa, TX']

# %%
df_cleaned[df_cleaned['RegionName'].str.contains('new york', case=False, na=False)]
# Out:
#    RegionID  SizeRank    RegionName StateName  2018-02-HomeValue  \
# 1    394913         1  New York, NY        NY      468313.430126
#
#    2018-02-DaysPending  2018-02-PriceCut  2018-03-HomeValue  \
# 1                 68.0           16000.0      470102.249154
#
#    2018-03-DaysPending  2018-03-PriceCut  ...  2024-02-PriceCut  \
# 1                 63.0           19751.5  ...           25000.0
#
#    2024-03-HomeValue  2024-03-DaysPending  2024-03-PriceCut  \
# 1      646508.747102                 55.0           25000.0
#
#    2024-04-HomeValue  2024-04-DaysPending  2024-04-PriceCut  \
# 1       652619.09994                 51.0           26000.0
#
#    2024-05-HomeValue  2024-05-DaysPending  2024-05-PriceCut
# 1      657279.223513                 47.0           30000.0
#
# [1 rows x 232 columns]

# %%
df_cleaned[df_cleaned['RegionName'].str.contains('Charlotte', case=False, na=False)]
# Out:
#      RegionID  SizeRank           RegionName StateName  2018-02-HomeValue  \
# 23     394458        23        Charlotte, NC        NC      216161.401546
# 205    394459       212  Charlottesville, VA        VA      297316.304015
#
#      2018-02-DaysPending  2018-02-PriceCut  2018-03-HomeValue  \
# 23                  35.0            8400.0      217823.140728
# 205                 62.0           10000.0      298885.449819
#
#      2018-03-DaysPending  2018-03-PriceCut  ...  2024-02-PriceCut  \
# 23                  30.0            9900.0  ...           10000.0
# 205                 53.0           10000.0  ...           19001.0
#
#      2024-03-HomeValue  2024-03-DaysPending  2024-03-PriceCut  \
# 23       382625.496534                 31.0           10000.0
# 205      439172.811221                 24.0           15000.0
#
#      2024-04-HomeValue  2024-04-DaysPending  2024-04-PriceCut  \
# 23       384749.010838                 29.0           10000.0
# 205      442486.555282                 23.0           17000.0
#
#      2024-05-HomeValue  2024-05-DaysPending  2024-05-PriceCut
# 23       386370.804768                 28.0           10000.0
# 205      445589.867659                 22.0           16000.0
#
# [2 rows x 232 columns]

# %%
df_cleaned[df_cleaned['RegionName'].str.contains('Miami', case=False, na=False)]
# Out:
#      RegionID  SizeRank RegionName StateName  2018-02-HomeValue  \
# 8      394856         8  Miami, FL        FL      274876.172488
# 787    394855       817  Miami, OK        OK       78969.143376
#
#      2018-02-DaysPending  2018-02-PriceCut  2018-03-HomeValue  \
# 8                   60.0           10000.0      276057.752522
# 787                  NaN               NaN       79808.105892
#
#      2018-03-DaysPending  2018-03-PriceCut  ...  2024-02-PriceCut  \
# 8                   61.0           10000.0  ...           15000.0
# 787                  NaN               NaN  ...               NaN
#
#      2024-03-HomeValue  2024-03-DaysPending  2024-03-PriceCut  \
# 8        486401.664815                 67.0           14900.0
# 787      119048.853711                 64.0               NaN
#
#      2024-04-HomeValue  2024-04-DaysPending  2024-04-PriceCut  \
# 8        488391.399156                 68.0           13000.0
# 787      121064.145455                 57.0               NaN
#
#      2024-05-HomeValue  2024-05-DaysPending  2024-05-PriceCut
# 8        490088.201516                 69.0           14000.0
# 787      123090.695380                 57.0               NaN
#
# [2 rows x 232 columns]

# %%
df_cleaned[df_cleaned['RegionName'].str.contains('New York', case=False, na=False)]
# Out:
#    RegionID  SizeRank    RegionName StateName  2018-02-HomeValue  \
# 1    394913         1  New York, NY        NY      468313.430126
#
#    2018-02-DaysPending  2018-02-PriceCut  2018-03-HomeValue  \
# 1                 68.0           16000.0      470102.249154
#
#    2018-03-DaysPending  2018-03-PriceCut  ...  2024-02-PriceCut  \
# 1                 63.0           19751.5  ...           25000.0
#
#    2024-03-HomeValue  2024-03-DaysPending  2024-03-PriceCut  \
# 1      646508.747102                 55.0           25000.0
#
#    2024-04-HomeValue  2024-04-DaysPending  2024-04-PriceCut  \
# 1       652619.09994                 51.0           26000.0
#
#    2024-05-HomeValue  2024-05-DaysPending  2024-05-PriceCut
# 1      657279.223513                 47.0           30000.0
#
# [1 rows x 232 columns]

# %%
# Filter for North Carolina (NC), New York (NY), and Florida (FL)
nc_cities = df_cleaned[df_cleaned['StateName'] == 'NC']
ny_cities = df_cleaned[df_cleaned['StateName'] == 'NY']
fl_cities = df_cleaned[df_cleaned['StateName'] == 'FL']

# Check if there are any cities found in each state
print(f"Cities in North Carolina (NC): {nc_cities.shape[0]}")
print(f"Cities in New York (NY): {ny_cities.shape[0]}")
print(f"Cities in Florida (FL): {fl_cities.shape[0]}")
# Out:
# Cities in North Carolina (NC): 37
# Cities in New York (NY): 26
# Cities in Florida (FL): 29

# %%
df.isnull().sum()
# Out:
# RegionID                 0
# SizeRank                 0
# RegionName               0
# StateName                1
# 2018-02-HomeValue        1
#                       ...
# 2024-04-DaysPending    177
# 2024-04-CutRaw         234
# 2024-05-HomeValue        0
# 2024-05-DaysPending    158
# 2024-05-CutRaw         174
# Length: 232, dtype: int64

# %%
df.dropna()
# Out:
#      RegionID  SizeRank         RegionName StateName  2018-02-HomeValue  \
# 1      394913         1       New York, NY        NY      468313.430126
# 2      753899         2    Los Angeles, CA        CA      629019.165765
# 3      394463         3        Chicago, IL        IL      229741.266973
# 4      394514         4         Dallas, TX        TX      241533.231800
# 5      394692         5        Houston, TX        TX      208651.872272
# ..        ...       ...                ...       ...                ...
# 466    394955       479        Palatka, FL        FL      106686.723888
# 476    394877       491  Morehead City, NC        NC      262059.754953
# 504    394629       520     Georgetown, SC        SC      229302.947359
# 544    394411       561        Branson, MO        MO      143943.620254
# 552    753920       569         Sonora, CA        CA      304615.385615
#
#      2018-02-DaysPending  2018-02-CutRaw  2018-03-HomeValue  \
# 1                   68.0         16000.0      470102.249154
# 2                   33.0         20000.0      636850.139417
# 3                   52.0          8000.0      231317.183706
# 4                   46.0          8562.0      243401.180622
# 5                   51.0         10000.0      209394.157749
# ..                   ...             ...                ...
# 466                 64.0         10000.0      106721.670681
# 476                 78.0         10000.0      262803.655249
# 504                 77.0          8100.0      230281.137068
# 544                 75.0          9000.0      144769.591667
# 552                 62.0         10000.0      306409.230256
#
#      2018-03-DaysPending  2018-03-CutRaw  ...  2024-02-CutRaw  \
# 1                   63.0         19751.5  ...         25000.0
# 2                   31.0         20000.0  ...         30000.5
# 3                   42.0          9100.0  ...         10000.0
# 4                   42.0          9900.0  ...         10000.0
# 5                   45.0         10000.0  ...         10000.0
# ..                   ...             ...  ...             ...
# 466                 95.0         10000.0  ...         10000.0
# 476                 79.0          7050.0  ...         12100.0
# 504                 81.0          6000.0  ...         10055.0
# 544                 74.0          5100.0  ...          5325.0
# 552                 45.0         10000.0  ...         11000.0
#
#      2024-03-HomeValue  2024-03-DaysPending  2024-03-CutRaw  \
# 1        646508.747102                 55.0         25000.0
# 2        952665.578913                 32.0         34000.0
# 3        316875.294320                 29.0         10000.0
# 4        379972.349667                 42.0         10000.0
# 5        309138.260511                 53.0         10000.0
# ..                 ...                  ...             ...
# 466      211000.189801                 55.0         10000.0
# 476      453796.905310                 39.0         11500.0
# 504      389546.746517                 43.0         10500.0
# 544      255085.380274                 68.0          5500.0
# 552      399551.022811                109.0         14995.0
#
#      2024-04-HomeValue  2024-04-DaysPending  2024-04-CutRaw  \
# 1        652619.099940                 51.0         26000.0
# 2        956266.687926                 29.0         40012.0
# 3        319764.144323                 25.0         10000.0
# 4        380957.392395                 38.0         10000.0
# 5        310167.057071                 47.0         10000.0
# ..                 ...                  ...             ...
# 466      213185.595995                 86.0         10000.0
# 476      455808.067846                 49.0         15000.0
# 504      392872.335776                 68.0         10000.0
# 544      255423.322460                 67.0         10000.0
# 552      400993.970354                 68.0         19100.0
#
#      2024-05-HomeValue  2024-05-DaysPending  2024-05-CutRaw
# 1        657279.223513                 47.0         30000.0
# 2        962388.491425                 28.0         40000.0
# 3        321897.252361                 23.0         10000.0
# 4        381103.625851                 38.0         10000.0
# 5        310706.915311                 46.0         10000.0
# ..                 ...                  ...             ...
# 466      214949.862841                 78.0         10000.0
# 476      457672.048408                 58.0         15000.0
# 504      396124.409855                 57.0         10000.0
# 544      254828.419318                 46.0          7000.0
# 552      401768.945976                 52.0         15000.0
#
# [122 rows x 232 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#      RegionID  SizeRank       RegionName StateName  2018-02-HomeValue  \
# 0      102001         0    United States       NaN      225746.614318
# 1      394913         1     New York, NY        NY      468313.430126
# 2      753899         2  Los Angeles, CA        CA      629019.165765
# 3      394463         3      Chicago, IL        IL      229741.266973
# 4      394514         4       Dallas, TX        TX      241533.231800
# ..        ...       ...              ...       ...                ...
# 890    753929       935       Zapata, TX        TX      117239.787864
# 891    394743       936    Ketchikan, AK        AK      296669.873256
# 892    753874       937        Craig, CO        CO      168760.073073
# 893    395188       938       Vernon, TX        TX       70971.082716
# 894    394767       939       Lamesa, TX        TX       84676.368978
#
#      2018-02-DaysPending  2018-02-CutRaw  2018-03-HomeValue  \
# 0                   52.0          7600.0      227155.648994
# 1                   68.0         16000.0      470102.249154
# 2                   33.0         20000.0      636850.139417
# 3                   52.0          8000.0      231317.183706
# 4                   46.0          8562.0      243401.180622
# ..                   ...             ...                ...
# 890                  NaN             NaN      117590.084777
# 891                  NaN             NaN      299776.694492
# 892                  NaN             NaN      169634.403620
# 893                  NaN             NaN       71692.233288
# 894                  NaN             NaN       85494.891208
#
#      2018-03-DaysPending  2018-03-CutRaw  ...  2024-02-CutRaw  \
# 0                   48.0          8900.0  ...         10000.0
# 1                   63.0         19751.5  ...         25000.0
# 2                   31.0         20000.0  ...         30000.5
# 3                   42.0          9100.0  ...         10000.0
# 4                   42.0          9900.0  ...         10000.0
# ..                   ...             ...  ...             ...
# 890                  NaN             NaN  ...             NaN
# 891                  NaN             NaN  ...             NaN
# 892                  NaN             NaN  ...             NaN
# 893                  NaN             NaN  ...             NaN
# 894                  NaN             NaN  ...             NaN
#
#      2024-03-HomeValue  2024-03-DaysPending  2024-03-CutRaw  \
# 0        357374.362080                 42.0         10000.0
# 1        646508.747102                 55.0         25000.0
# 2        952665.578913                 32.0         34000.0
# 3        316875.294320                 29.0         10000.0
# 4        379972.349667                 42.0         10000.0
# ..                 ...                  ...             ...
# 890      116585.863681                  NaN             NaN
# 891      387319.314967                  NaN             NaN
# 892      285342.615851                  NaN             NaN
# 893       90770.425466                  NaN             NaN
# 894       85624.257188                  NaN             NaN
#
#      2024-04-HomeValue  2024-04-DaysPending  2024-04-CutRaw  \
# 0        359240.114070                 38.0         10000.0
# 1        652619.099940                 51.0         26000.0
# 2        956266.687926                 29.0         40012.0
# 3        319764.144323                 25.0         10000.0
# 4        380957.392395                 38.0         10000.0
# ..                 ...                  ...             ...
# 890      118043.845001                  NaN             NaN
# 891      388840.396336                  NaN             NaN
# 892      286124.694239                  NaN             NaN
# 893       91504.904635                  NaN             NaN
# 894       85839.074267                  NaN             NaN
#
#      2024-05-HomeValue  2024-05-DaysPending  2024-05-CutRaw
# 0        360681.294250                 37.0         10000.0
# 1        657279.223513                 47.0         30000.0
# 2        962388.491425                 28.0         40000.0
# 3        321897.252361                 23.0         10000.0
# 4        381103.625851                 38.0         10000.0
# ..                 ...                  ...             ...
# 890      119697.355634                  NaN             NaN
# 891      389962.681122                  NaN             NaN
# 892      287028.957463                  NaN             NaN
# 893       92149.470030                  NaN             NaN
# 894       86743.423553                  NaN             NaN
#
# [895 rows x 232 columns]

# %%
# city = 'Charlotte, NC'
# city = 'Miami, FL'
# city = 'New York, NY'
home_value = 750000

# %% [markdown]
# EACH CITY NEEDS TO BE CLEANED + ALIGNED W/ COLUMNS ALLOCATED

# %%
# Target vs. Current Search 
states = ['North Carolina', 'Florida', 'New York']
state_data = {}

# We only want the clean data
for state_name in states:
    # Filter by state
    state = df_cleaned[df_cleaned['StateName'] == state_name]
    
    #Confirmatioin of data
    if state.empty:
        print(f"No data available for the state: {state_name}")
        continue 

    
    state_data[state_name] = state['PriceCut']  

plt.figure(figsize=(10, 6))
sns.boxplot(data=list(state_data.values()), labels=state_data.keys(), palette='Set2')

plt.title('Price Distribution for Selected States', fontsize=14)
plt.xlabel('States', fontsize=12)
plt.ylabel('Price Cut (USD)', fontsize=12)
plt.grid(True)
plt.show()
# Out:
# No data available for the state: North Carolina
# No data available for the state: Florida
# No data available for the state: New York

# %% [markdown]
# NEED HOME VALUE

# %%
home_value_cols = [col for col in df_cleaned.columns if 'HomeValue' in col]
print(home_value_cols)  # Check the column names
# Out:
# ['2018-02-HomeValue', '2018-03-HomeValue', '2018-04-HomeValue', '2018-05-HomeValue', '2018-06-HomeValue', '2018-07-HomeValue', '2018-08-HomeValue', '2018-09-HomeValue', '2018-10-HomeValue', '2018-11-HomeValue', '2018-12-HomeValue', '2019-01-HomeValue', '2019-02-HomeValue', '2019-03-HomeValue', '2019-04-HomeValue', '2019-05-HomeValue', '2019-06-HomeValue', '2019-07-HomeValue', '2019-08-HomeValue', '2019-09-HomeValue', '2019-10-HomeValue', '2019-11-HomeValue', '2019-12-HomeValue', '2020-01-HomeValue', '2020-02-HomeValue', '2020-03-HomeValue', '2020-04-HomeValue', '2020-05-HomeValue', '2020-06-HomeValue', '2020-07-HomeValue', '2020-08-HomeValue', '2020-09-HomeValue', '2020-10-HomeValue', '2020-11-HomeValue', '2020-12-HomeValue', '2021-01-HomeValue', '2021-02-HomeValue', '2021-03-HomeValue', '2021-04-HomeValue', '2021-05-HomeValue', '2021-06-HomeValue', '2021-07-HomeValue', '2021-08-HomeValue', '2021-09-HomeValue', '2021-10-HomeValue', '2021-11-HomeValue', '2021-12-HomeValue', '2022-01-HomeValue', '2022-02-HomeValue', '2022-03-HomeValue', '2022-04-HomeValue', '2022-05-HomeValue', '2022-06-HomeValue', '2022-07-HomeValue', '2022-08-HomeValue', '2022-09-HomeValue', '2022-10-HomeValue', '2022-11-HomeValue', '2022-12-HomeValue', '2023-01-HomeValue', '2023-02-HomeValue', '2023-03-HomeValue', '2023-04-HomeValue', '2023-05-HomeValue', '2023-06-HomeValue', '2023-07-HomeValue', '2023-08-HomeValue', '2023-09-HomeValue', '2023-10-HomeValue', '2023-11-HomeValue', '2023-12-HomeValue', '2024-01-HomeValue', '2024-02-HomeValue', '2024-03-HomeValue', '2024-04-HomeValue', '2024-05-HomeValue']

# %%
years = sorted(set([col[:4] for col in df_cleaned.columns if 'HomeValue' in col]))

# %% [markdown]
# EDA:

# %%
df_cleaned = df.dropna()
numeric_cols = df_cleaned.select_dtypes(include=[np.number]).columns
df_numeric = df_cleaned[numeric_cols]
Q1 = df_numeric.quantile(0.25)
Q3 = df_numeric.quantile(0.75)
IQR = Q3 - Q1
df_numeric_cleaned = df_numeric[~((df_numeric < (Q1 - 1.5 * IQR)) | (df_numeric > (Q3 + 1.5 * IQR))).any(axis=1)]
df_cleaned = df_cleaned.loc[df_numeric_cleaned.index]
print('Data Cleaning AS EXPECTED')
# Out:
# Data Cleaning AS EXPECTED

# %% [markdown]
# DATA ENTIRE POPULATION: HOME VALUE BOX-PLOT (display distribution of avg. home value 2018-2024

# %% [markdown]
# 1) USING FOR-LOOP: We will need to take ONLY the home value columns for this distribution

# %%
# Extract the year format from column names (e.g., '2018', '2019', etc.)
years = sorted(set([col[:4] for col in df_cleaned.columns if 'HomeValue' in col]))

boxplot_data = []

for year in years:
    
    year_home_values = []
    for city_name in cities:
        city_data = df_cleaned[df_cleaned['RegionName'] == city_name]
        home_value_col = f"{year}-02-HomeValue"  
        if home_value_col in city_data.columns:
            year_home_values.append(city_data[home_value_col].values)
        else:
            year_home_values.append(np.nan) 

    boxplot_data.append(year_home_values)

# %% [markdown]
# 2) var_name & value_name to paint a picture (easier use of dependent variable analysis)

# %% [markdown]
# 3) color_map can be used: RED TO IDENTIFY HIGH PRICES & BLUE TO DEFINE LOWER PRICES

# %%
flat_home_values = [value for sublist in boxplot_data for value in sublist if not np.isnan(value)]
norm = Normalize(vmin=np.min(flat_home_values), vmax=np.max(flat_home_values))  
cmap = plt.get_cmap("coolwarm")  

# Mean home values since my cities weren't available but the data was useful
color_map = [ScalarMappable(norm=norm, cmap=cmap).to_rgba(np.mean(home_values)) for home_values in boxplot_data]

plt.figure(figsize=(14, 7))

###sns.boxplot generates color palette
sns.boxplot(data=boxplot_data, palette=color_map)

plt.xticks(ticks=range(len(years)), labels=years, rotation=45, fontsize=12)
plt.title('Distribution of Home Values Over Time by Year', fontsize=16)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Home Value (USD)', fontsize=14)
plt.tight_layout()
plt.show()

# %%
days_pending_cols = [col for col in df.columns if 'DaysPending' in col]
days_pending_mean = df_cleaned[days_pending_cols].mean()
days_pending_mean.index = [col[:4] for col in days_pending_mean.index]
days_pending_mean_by_year = days_pending_mean.groupby(days_pending_mean.index).mean()

plt.figure(figsize=(14, 7))
days_pending_mean_by_year.plot(color='coral')
plt.title('Average Days Pending Over Time - National USA Average')
plt.xlabel('Year')
plt.ylabel('Days Pending')
plt.grid(True)
plt.show()

# %%
home_values_cols = [col for col in df_cleaned.columns if 'HomeValue' in col]
home_values_mean = df_cleaned[home_values_cols].mean()
home_values_mean.index = [col[:4] for col in home_values_mean.index]

home_values_mean_by_year = home_values_mean.groupby(home_values_mean.index).mean()

# %%
plt.figure(figsize=(14, 7))
home_values_mean_by_year.plot(kind='area', color='skyblue', alpha=0.5)

plt.title('Average Home Values Over Time - National USA Average', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Home Value (USD)', fontsize=14)
plt.grid(True)
plt.show()
